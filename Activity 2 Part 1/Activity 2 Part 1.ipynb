# %% [markdown]
# # Activity 2.1

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.fft import fft2, ifft2, fftshift

def circle(N, r):    # generate circle, N -no. of pixels, r - radius

    x = np.linspace(-1,1,N)              # 1d
    y = x                                # make same number of columns
    X,Y = np.meshgrid(x,y)               # make NxN arrays
    R = np.sqrt(X**2+Y**2)               # radius/distance from center formula
    circle = np.zeros(np.shape(R))       # initiate empty array
    r = r/N                            # scale radius from 0 to 1
    circle[np.where(R<r)] = 1.0          # change pixels within a radius to create a circle
    
    return circle

def sinusoid(N, f):  # generate sinusoid, N - no. of pixels, f - frequency
    x = np.linspace(-1,1,N)
    y = np.sin(f*2*np.pi*x)                # sin(2f*pi x) f determines frequency per unit
    X,Y = np.meshgrid(x,y)
    sinusoid = np.transpose(Y)
    return sinusoid

N = 256
A = sinusoid(N, 10)

plt.imshow(A, cmap='gray')        # since array has binary values, there will be 2 colors
# plt.imsave('sinusoid_100.png', A, cmap='gray')

# FA = np.fft.fft2(A)
# plt.imshow(abs(FA), cmap='gray')

# FAshifted = np.fft.fftshift(FA)
# plt.imshow(abs(FAshifted), cmap = 'hot')
# plt.imsave('FAshiftedcircl1.png', abs(FAshifted), cmap='hot')

# %%
FA = np.fft.fft2(A)
plt.imshow(abs(FA), cmap='gray')

# %%
FAshifted = np.fft.fftshift(FA)
plt.imshow(abs(FAshifted), cmap = 'hot')
# plt.imsave('FAshiftedsinusoid_10.png', abs(FAshifted), cmap='hot')

# %%
from numpy.fft import fft2, ifft2
import cv2
dark_img = cv2.imread('cal sith eyes.jpg')

dark_img_gray = cv2.cvtColor(dark_img, cv2.COLOR_BGR2GRAY)

plt.figure()
plt.subplot(1,3,1)
plt.imshow(dark_img_gray, cmap='gray')
# plt.imsave('cal.png', dark_img_gray, cmap='gray')

Irec = fft2(fft2(dark_img_gray))
plt.subplot(1,3,2)
plt.imshow(abs(Irec), cmap='gray')
# plt.imsave('FFT_FFT_cal.png', abs(Irec), cmap='gray')

Irec2 = ifft2(fft2(dark_img_gray))
plt.subplot(1,3,3)
plt.imshow(abs(Irec2), cmap='gray')
# plt.imsave('FFT_IFFT_cal.png', abs(Irec2), cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_11835/2684609413.py in <module>
#       1 from numpy.fft import fft2, ifft2
# ----> 2 import cv2
#       3 dark_img = cv2.imread('cal sith eyes.jpg')
#       4
#       5 dark_img_gray = cv2.cvtColor(dark_img, cv2.COLOR_BGR2GRAY)
#
# ModuleNotFoundError: No module named 'cv2'

# %%
nip = plt.imread('NIP.tif')

plt.imshow(nip)

# %%
N=256
aperture = circle(N,100)
# aperture = sinusoid(4)
plt.imshow(aperture, cmap='gray')
# plt.imsave('aperture_sine.png', aperture, cmap='gray')

# %%
aperture_fftshift = fftshift(aperture)    # ftshift the aperture
nip_fft = fft2(nip[:,:,1])                    # ft the nip    
conv = nip_fft*aperture_fftshift              # multiply
conv_inv = ifft2(conv)                        # inverse ft

plt.imshow(abs(conv_inv), cmap='gray')
# plt.imsave('nip_sine.png',abs(conv_inv), cmap='gray')

# %%
rain = plt.imread('rain.tif')
a = plt.imread('a.tif')
i = plt.imread('i.tif')

plt.imshow(rain, cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_11835/253079302.py in <module>
#       1 rain = plt.imread('rain.tif')
# ----> 2 a = plt.imread('a.tif')
#       3 i = plt.imread('i.tif')
#       4
#       5 plt.imshow(rain, cmap='gray')
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py in imread(fname, format)
#    2158 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2159 def imread(fname, format=None):
# -> 2160     return matplotlib.image.imread(fname, format)
#    2161
#    2162
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/image.py in imread(fname, format)
#    1558                     response = io.BytesIO(response.read())
#    1559                 return imread(response, format=ext)
# -> 1560     with img_open(fname) as image:
#    1561         return (_pil_png_to_float_array(image)
#    1562                 if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#
# ~/anaconda3/lib/python3.9/site-packages/PIL/Image.py in open(fp, mode, formats)
#    3090
#    3091     if filename:
# -> 3092         fp = builtins.open(filename, "rb")
#    3093         exclusive_fp = True
#    3094
#
# FileNotFoundError: [Errno 2] No such file or directory: 'a.tif'

# %%
plt.imshow(a, cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_11835/1860831360.py in <module>
# ----> 1 plt.imshow(a, cmap='gray')
#
# NameError: name 'a' is not defined

# %%
rain_fft2 = fft2(rain)
a_fft2 = fft2(a)
i_fft2 = fft2(i)

prod_a = np.conj(a_fft2)*rain_fft2
prod_i = np.conj(i_fft2)*rain_fft2

result_a = ifft2(prod_a)
result_i = ifft2(prod_i)

plt.imshow(fftshift(abs(result_a)))
# plt.imsave('a_locations.png',fftshift(abs(result_a)))

# %%
plt.imshow(i, cmap='gray')

# %%
plt.imshow(fftshift(abs(result_i)))
# plt.imsave('i_locations.png',fftshift(abs(result_i)))
